# %%
#Create a Python dictionary called playlist_prices with at least 5 key-value pairs where the key is a Spotify playlist name (as a string) and the value is the playlist's price (as an integer). Print the dictionary.
playlist_prices = {
    "Top Hits": 199,
    "Chill Vibes": 149,
    "Workout Mix": 249,
    "Party Beats": 299,
    "Study Focus": 179
}

print(playlist_prices)
# Out:
# {'Top Hits': 199, 'Chill Vibes': 149, 'Workout Mix': 249, 'Party Beats': 299, 'Study Focus': 179}

# %%
#2)Write a function update_playlist_price(playlist, new_price) that updates the price of a given playlist in the playlist_prices dictionary. Test it by updating the price of any one playlist and printing the updated dictionary.
playlist_prices = {
    "Top Hits": 199,
    "Chill Vibes": 149,
    "Workout Mix": 249,
    "Party Beats": 299,
    "Study Focus": 179
}
def update_playlist_price(playlist, new_price):
    playlist_prices[playlist] = new_price
update_playlist_price("Party Beats", 350)
print(playlist_prices)
# Out:
# {'Top Hits': 199, 'Chill Vibes': 149, 'Workout Mix': 249, 'Party Beats': 350, 'Study Focus': 179}

# %%
#3)Remove a playlist from the playlist_prices dictionary using the del statement. Print the dictionary after deletion to confirm the change.
playlist_prices = {
    "Top Hits": 199,
    "Chill Vibes": 149,
    "Workout Mix": 249,
    "Party Beats": 350,
    "Study Focus": 179
}

del playlist_prices["Chill Vibes"]
print(playlist_prices)
# Out:
# {'Top Hits': 199, 'Workout Mix': 249, 'Party Beats': 350, 'Study Focus': 179}

# %%
#4)Given two sets: set1 contains the names of restaurants you have ordered from on Zomato, and set2 contains the names of restaurants you have ordered from on Swiggy, find and print the union and intersection of these sets.<br><br><em><strong>Hint:</strong> Use the union() and intersection() methods of Python sets.</em>

set1 = {"Dominos", "McDonalds", "KFC", "Burger King"}
set2 = {"KFC", "Pizza Hut", "Burger King", "Subway"}
all_restaurants = set1.union(set2)

common_restaurants = set1.intersection(set2)

print("Union:", all_restaurants)
print("Intersection:", common_restaurants)
# Out:
# Union: {'McDonalds', 'Burger King', 'Dominos', 'Pizza Hut', 'Subway', 'KFC'}
# Intersection: {'KFC', 'Burger King'}
