# %%
#1)Use the math module to calculate the square root, factorial, and value of pi for given numbers, and print each result.
import math

num1 = 25
num2 = 5

print("Square Root:", math.sqrt(num1))
print("Factorial:", math.factorial(num2))
print("Value of Pi:", math.pi)
# Out:
# Square Root: 5.0
# Factorial: 120
# Value of Pi: 3.141592653589793

# %%
#2)Write a script that lists all files in your current directory using the os module, and prints only those files with a .jpg or .png extension.<br><br><em><strong>Hint:</strong> Use os.listdir() and string methods to filter file names.</em>
import os

files = os.listdir()

for file in files:
    if file.endswith(".jpg") or file.endswith(".png"):
        print(file)

# %%
#3)Create a Python program that accepts a date in 'YYYY-MM-DD' format from the user and displays the day of the week using the datetime module.
from datetime import datetime

# Accept date from user
date_input = input("Enter a date (YYYY-MM-DD): ")

# Convert string to date
date_obj = datetime.strptime(date_input, "%Y-%m-%d")

# Display day of the week
print("Day of the week:", date_obj.strftime("%A"))
# Out:
# Enter a date (YYYY-MM-DD):  2026-06-10
# Day of the week: Wednesday

# %%
#4)Build a simple custom module named insta_utils.py with a function format_follower_count(n) that returns '1.5K' for 1500 and '2.3M' for 2300000. Import and use this function in another script to display formatted counts for 3 sample numbers.
with open("insta_utils.py", "w") as file:
    file.write("""
def format_follower_count(n):
    if n >= 1000000:
        return f"{n / 1000000:.1f}M"
    elif n >= 1000:
        return f"{n / 1000:.1f}K"
    else:
        return str(n)
""")

# %%
from insta_utils import format_follower_count

followers = [1500, 2300000, 850]

for count in followers:
    print(format_follower_count(count))
# Out:
# 1.5K
# 2.3M
# 850

# %%
#5)Create a new virtual environment using venv, activate it, and install the statistics and requests packages via pip. Then, write a script that uses statistics.mean() to calculate the average of a list of numbers.
# !python -m venv myenv

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\jayde\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jayde\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jayde\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayde\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayde\anaconda3\lib\site-packages (from requests) (2025.11.12)

# %%
import statistics

numbers = [10, 20, 30, 40, 50]

average = statistics.mean(numbers)

print("Numbers:", numbers)
print("Average:", average)
# Out:
# Numbers: [10, 20, 30, 40, 50]
# Average: 30
